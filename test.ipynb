# %%
import pandas as pd

# %%
df = pd.read_excel("data/Instructional_Design_Models.xlsx")

# %%
df
# Out:
#     Unnamed: 0                                 Model Name  \
# 0            1                                      ADDIE
# 1            2                       Dick and Carey model
# 2            3                               Assure model
# 3            4  Backward Design (Understanding By Design)
# 4            5                          Kemp Design Model
# ..         ...                                        ...
# 59          60                          Flipped Classroom
# 60          61  Merrill’s Principles of Instruction (MPI)
# 61          62                           Tyler-Taba Model
# 62          63             Design-based research approach
# 63          64                     Problem-based learning
#
#                                      Short Background  \
# 0   ADDIE was designed in 1975, originally for the...
# 1   Dick and Carey Instructional Model (also known...
# 2   ASSURE is an instructional design model that h...
# ...
